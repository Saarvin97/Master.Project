# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
Data=pd.read_excel('/content/drive/MyDrive/undersampled label data.xlsx')

# %%
X = Data['Lemma']
y = Data['Manual Label']

# %%
from sklearn.model_selection import train_test_split
import numpy as np

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()
X_train = vectorizer.fit_transform(X_train.ravel())
X_val = vectorizer.transform(X_val.ravel())

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import classification_report
y_pred2 = rf.predict(X_val)
print(classification_report(y_val, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.92      0.68        49
#            1       0.80      0.29      0.43        55
#
#     accuracy                           0.59       104
#    macro avg       0.67      0.60      0.55       104
# weighted avg       0.68      0.59      0.54       104

# %%
Data2=pd.read_excel('/content/drive/MyDrive/FYP VIVA Presentation/unlabelled data2.xlsx')

# %%
X_test = Data2['Lemma']
X_test_transformed = vectorizer.transform(X_test)
y_pred_test = rf.predict(X_test_transformed)

# %%
y_true=Data2['clusters']

# %%
print(classification_report(y_true, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.13      0.96      0.23       880
#            1       0.89      0.05      0.10      5765
#
#     accuracy                           0.17      6645
#    macro avg       0.51      0.51      0.17      6645
# weighted avg       0.79      0.17      0.12      6645
